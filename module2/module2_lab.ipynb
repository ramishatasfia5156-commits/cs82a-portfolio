# %% [markdown]
# # Module 2 Lab 1: Python Warm-Up + First Push
#
# **Name:** Ramisha Tasfia
#
# **Repo:** https://github.com/ramishatasfia5156-commits/cs82a-portfolio
#
# This notebook works through Steps 1–6 of the Module 2 Lab 1 assignment: core Python constructs, a dictionary, and loading/inspecting `chickwts.csv` with pandas.

# %% [markdown]
# ## Step 1: Wages with f-strings

# %%
name = "Ramisha Tasfia"
hourly_wage = 32.00
hours = 20
weekly_pay = hourly_wage * hours
print(f"{name} earns {weekly_pay} per week")
# Out:
# Ramisha Tasfia earns 640.0 per week

# %% [markdown]
# ## Step 2: Count the warm days

# %%
temps = [61, 65, 72, 58, 70, 74, 68]
warm_days = 0
for t in temps:
    if t > 65:
        warm_days = warm_days + 1
print(warm_days)
# Out:
# 4

# %% [markdown]
# ## Step 3: Write a temperature converter

# %%
def to_celsius(f):
    return (f - 32) * 5 / 9

print(round(to_celsius(temps[0]), 1))
# Out:
# 16.1

# %% [markdown]
# ## Step 4: A movie dictionary

# %%
movie = {"title": "Inception", "year": 2010, "rating": 8.8}

for key, value in movie.items():
    print(key, ":", value)
# Out:
# title : Inception
# year : 2010
# rating : 8.8

# %% [markdown]
# ## Step 5: Load and inspect chickwts.csv

# %%
import pandas as pd

df = pd.read_csv("chickwts.csv")
df.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
df.shape
# Out:
# (71, 2)

# %%
df.describe()
# Out:
#            weight
# count   71.000000
# mean   261.309859
# std     78.073700
# min    108.000000
# 25%    204.500000
# 50%    258.000000
# 75%    323.500000
# max    423.000000

# %% [markdown]
# ## Step 6: Interpret describe()
#
# It tells me that the average weight of chicks was approximately 261 grams, and since the middle value is 258 g, it's close to average. Also it indicates that the distribution of weights is fairly wide and somewhat non-random. The lowest weight recorded was 108 grams while the highest was 423 grams. This suggests there could be significant differences in how well the various feeds work with regard to growth. To get a clearer picture of these differences, I would have to break down the data into each feed type rather than treating them as a whole.

# %% [markdown]
# ## Appendix: AI Use Disclosure
#
# **Tool used:** Claude (Anthropic), via Claude Code / Cowork.
#
# **How it was used:** Used Claude to help build the code cells for Steps 1-5, following the patterns from the lab's tutorials. I reviewed and ran every cell myself and chose my own values for Step 1. I wrote the Step 6 interpretation myself.
#
# **Key prompts:**
# - "Build the Module 2 Lab 1 notebook (steps 1-5) following the tutorial patterns exactly, using chickwts.csv."
